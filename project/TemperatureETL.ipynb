# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# # Load the Data

# %%
df = pd.read_csv('https://data.humdata.org/dataset/469a7757-302c-4176-bf82-4a4523feb586/resource/5419549c-8d27-497c-8a7a-9d849a86cbca/download/climate-change_deu.csv')
df
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1           Germany            DEU        2021
# 2           Germany            DEU        2020
# 3           Germany            DEU        2019
# 4           Germany            DEU        2018
# ...             ...            ...         ...
# 1744        Germany            DEU        1964
# 1745        Germany            DEU        1963
# 1746        Germany            DEU        1962
# 1747        Germany            DEU        1961
# 1748        Germany            DEU        1960
#
#                                 Indicator Name     Indicator Code  \
# 0                              #indicator+name    #indicator+code
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 4                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# ...                                        ...                ...
# 1744  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1745  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1746  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1747  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1748  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#                      Value
# 0     #indicator+value+num
# 1                   165910
# 2                   165950
# 3                   166660
# 4                   166450
# ...                    ...
# 1744                71.891
# 1745                71.826
# 1746                71.762
# 1747                71.697
# 1748                71.384
#
# [1749 rows x 6 columns]

# %%
df = pd.read_csv('https://data.humdata.org/dataset/469a7757-302c-4176-bf82-4a4523feb586/resource/5419549c-8d27-497c-8a7a-9d849a86cbca/download/climate-change_deu.csv')
df

# %%
df.dropna()
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1           Germany            DEU        2021
# 2           Germany            DEU        2020
# 3           Germany            DEU        2019
# 4           Germany            DEU        2018
# ...             ...            ...         ...
# 1744        Germany            DEU        1964
# 1745        Germany            DEU        1963
# 1746        Germany            DEU        1962
# 1747        Germany            DEU        1961
# 1748        Germany            DEU        1960
#
#                                 Indicator Name     Indicator Code  \
# 0                              #indicator+name    #indicator+code
# 1                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 2                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 3                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# 4                   Agricultural land (sq. km)     AG.LND.AGRI.K2
# ...                                        ...                ...
# 1744  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1745  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1746  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1747  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1748  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#                      Value
# 0     #indicator+value+num
# 1                   165910
# 2                   165950
# 3                   166660
# 4                   166450
# ...                    ...
# 1744                71.891
# 1745                71.826
# 1746                71.762
# 1747                71.697
# 1748                71.384
#
# [1749 rows x 6 columns]

# %%
df.to_csv("../data/output.csv")
